# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ENCUT = {'300': -.37128408E+01, '350': -.37192824E+01, '400': -.37141841E+01, '450':-.37122456E+01, '500': -.37127602E+01, 
         '550': -.37131796E+01, '600': -.37130761E+01, '650':-.37127902E+01, '700':-.37127738E+01}

KMESH = {'555': -.38174919E+01, '666': -.36503880E+01, '777': -.37569594E+01, '888': -.36824356E+01, '999': -.37293921E+01,
         '101010': -.37010555E+01, '111111': -.37218579E+01, '121212': -.37127902E+01, '131313': -.37169009E+01}

# %%
encut = list(ENCUT.keys())
encut_energies = list(ENCUT.values())

# %%
plt.plot(ENCUT.keys(), ENCUT.values())
plt.plot(ENCUT.keys(), ENCUT.values(), 'o', color = 'r')
plt.xlabel('ENCUT (eV)')
plt.ylabel('$E_{tot}$/atom (eV)')
plt.savefig('encut test', dpi=300, bbox_inches='tight')

# %%
plt.plot(KMESH.keys(), KMESH.values())
plt.plot(KMESH.keys(), KMESH.values(), 'o', color = 'r')
plt.xlabel('K-point mesh')
plt.ylabel('$E_{tot}$/atom (eV)')
plt.savefig('kmesh test', dpi=300, bbox_inches='tight')
